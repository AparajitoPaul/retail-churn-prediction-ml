# %% [markdown]
# # 5. Model Training
#
# ## Objective
#
# Train and compare multiple classification models to predict churn probability.
#
# ---
#
# ## Models Evaluated
#
# - Logistic Regression
# - Random Forest
# - XGBoost

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 1.7 MB/s eta 0:00:59
#    ---------------------------------------- 1.0/101.7 MB 1.9 MB/s eta 0:00:54
#     --------------------------------------- 1.3/101.7 MB 1.8 MB/s eta 0:00:57
#     --------------------------------------- 1.8/101.7 MB 1.9 MB/s eta 0:00:53
#     --------------------------------------- 2.1/101.7 MB 1.8 MB/s eta 0:00:57
#     --------------------------------------- 2.4/101.7 MB 1.7 MB/s eta 0:00:59
#    - -------------------------------------- 2.9/101.7 MB 1.8 MB/s eta 0:00:54
#    - -------------------------------------- 3.7/101.7 MB 2.0 MB/s eta 0:00:49
#    - -------------------------------------- 4.2/101.7 MB 2.1 MB/s eta 0:00:47
#    - -------------------------------------- 5.0/101.7 MB 2.3 MB/s eta 0:00:43
# ...

# %% [markdown]
# ## Data Preparation
#
# - Missing values handled
# - Standard scaling applied
# - Stratified train-test split

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.config import PROCESSED_DATA_PATH
from src.modeling import *

# Adding project root to Python path
sys.path.append(os.path.abspath(".."))

# %%
path = os.path.join(PROCESSED_DATA_PATH, "modeling_dataset.csv")
df = pd.read_csv(path)

df.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary    GapMean     GapStd  \
# 0     12346.0      225         12  77556.46  11.969697  40.413090
# 1     12347.0       29          6   4114.18   1.402062   8.835468
# 2     12348.0      148          4   1709.40   4.021277  16.192442
# 3     12349.0      307          3   2671.14   1.782178  16.200990
# 4     12350.0      210          1    334.40   0.000000   0.000000
#
#     BasketMean     BasketStd  RevenueTrend  DiversityRatio  SeasonalityRatio  \
# 0  6463.038333  22271.229481    388.591746        2.250000          0.996353
# 1   685.696667    373.823600      0.053552       17.833333          0.346018
# 2   427.350000    317.465363      1.152607        6.250000          0.522289
# 3   890.380000    620.785076     -0.015965       30.000000          0.525102
# 4   334.400000           NaN     -0.309559       17.000000          1.000000
#
#    Churn
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1

# %%
# Preparing Data
X_train, X_test, y_train, y_test, scaler = prepare_data(df)

# %%
log_model = train_logistic(X_train, y_train)
rf_model = train_random_forest(X_train, y_train)
xgb_model = train_xgboost(X_train, y_train)

# %% [markdown]
# ## Rationale
#
# Multiple models are compared to:
#
# - Evaluate linear vs non-linear boundaries
# - Assess ranking capability
# - Identify best-performing baseline
#
# No hyperparameter tuning is performed at this stage to maintain interpretability.

# %%
import joblib
from src.config import MODEL_PATH
import os

os.makedirs(MODEL_PATH, exist_ok=True)

joblib.dump(log_model, os.path.join(MODEL_PATH, "logistic_model.pkl"))
joblib.dump(scaler, os.path.join(MODEL_PATH, "scaler.pkl"))

print("Models saved successfully.")
# Out:
# Models saved successfully.
